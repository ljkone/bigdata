# %% [markdown]
# import matplotlib
# matplotlib.use('TkAgg')
# import matplotlib.pyplot as plot
# from datascience import *
#
# table7 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211110-utf-8.csv")
# table6 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211109-utf-8.csv")
# table5 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211109-1-utf-8.csv")
# table4 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211108-utf-8.csv")
# table3 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211107-utf-8.csv")
# table2 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211106-utf-8.csv")
# table1 = Table.read_table("D:\\lijunkang\\Desktop\\cj/20211105-utf-8.csv")
#
# name1 = input("请输入第一个名字：")
# name2 = input("请输入第二个名字：")
#
# def select(path,name):
#     a = path.where('姓名',name).column(11).item(0)
#     return a
#
# rank1 = make_array(select(table1,name1),select(table2,name1),select(table3,name1),select(table4,name1),select(table5,name1),select(table6,name1),select(table7,name1))
# results1 = Table().with_columns('考试序号',make_array(1,2,3,4,5,6,7),'班级名次',rank1)
#
# rank2 = make_array(select(table1,name2),select(table2,name2),select(table3,name2),select(table4,name2),select(table5,name2),select(table6,name2),select(table7,name2))
# results2 = Table().with_columns('考试序号',make_array(1,2,3,4,5,6,7),'班级名次',rank2)
#
# make = make_array(1,2,3,4,5,6,7)
# plot.plot(make,rank1,'o--',label=name1)
# plot.plot(make,rank2,'o--',label=name2)
# plot.title(name1 +'和'+ name2 + '比较')
# plot.xlabel('历届考试')
# plot.ylabel('年纪RANK')
# plot.axis([0,10,650,150])
# plot.legend(loc='upper right')
# plot.rcParams['font.sans-serif']= ['Microsoft YaHei']
# plot.grid()
# plot.show()

# %% [markdown]
# ![Figure_1.png](attachment:Figure_1.png)
